# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('laptop_prices.csv')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1275 non-null   object
#  3   Inches                1275 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           1275 non-null   object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'Ram', 'OS', 'Weight',
#        'Price_euros', 'Screen', 'ScreenW', 'ScreenH', 'Touchscreen',
#        'IPSpanel', 'RetinaDisplay', 'CPU_company', 'CPU_freq', 'CPU_model',
#        'PrimaryStorage', 'SecondaryStorage', 'PrimaryStorageType',
#        'SecondaryStorageType', 'GPU_company', 'GPU_model'],
#       dtype='object')

# %%
df.tail()
# Out:
#      Company                              Product            TypeName  Inches  \
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#       Ram          OS  Weight  Price_euros    Screen  ScreenW  ...  \
# 1270    4  Windows 10    1.80        638.0   Full HD     1920  ...
# 1271   16  Windows 10    1.30       1499.0  Quad HD+     3200  ...
# 1272    2  Windows 10    1.50        229.0  Standard     1366  ...
# 1273    6  Windows 10    2.19        764.0  Standard     1366  ...
# 1274    4  Windows 10    2.20        369.0  Standard     1366  ...
#
#       RetinaDisplay CPU_company CPU_freq                CPU_model  \
# ...

# %%
df.shape
# Out:
# (1275, 23)

# %%
df.isna().sum()
# Out:
# Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#             Inches          Ram       Weight  Price_euros      ScreenW  \
# count  1275.000000  1275.000000  1275.000000  1275.000000  1275.000000
# mean     15.022902     8.440784     2.040525  1134.969059  1900.043922
# std       1.429470     5.097809     0.669196   700.752504   493.346186
# min      10.100000     2.000000     0.690000   174.000000  1366.000000
# 25%      14.000000     4.000000     1.500000   609.000000  1920.000000
# 50%      15.600000     8.000000     2.040000   989.000000  1920.000000
# 75%      15.600000     8.000000     2.310000  1496.500000  1920.000000
# max      18.400000    64.000000     4.700000  6099.000000  3840.000000
#
#            ScreenH     CPU_freq  PrimaryStorage  SecondaryStorage
# count  1275.000000  1275.000000     1275.000000       1275.000000
# mean   1073.904314     2.302980      444.517647        176.069020
# std     283.883940     0.503846      365.537726        415.960655
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Company'>

# %%
df['OS'].value_counts().plot(kind = 'bar' , x = df['OS'])
# Out:
# <Axes: xlabel='OS'>

# %%
df['Touchscreen'].value_counts().plot(kind = 'pie', autopct = '%.2f%%' ,
title = 'TouchScreen')
# Out:
# <Axes: title={'center': 'TouchScreen'}, ylabel='count'>

# %%
df['Ram'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
df['CPU_company'].value_counts().plot(kind = 'pie' , autopct = '%.2f%%',
title = 'CPU_Company')
# Out:
# <Axes: title={'center': 'CPU_Company'}, ylabel='count'>

# %%
df['GPU_company'].value_counts().plot(kind = 'pie' , autopct = '%.2f%%',
title = 'GPU_Company')
# Out:
# <Axes: title={'center': 'GPU_Company'}, ylabel='count'>

# %%
df['IPSpanel'].value_counts().plot(kind = 'pie' , autopct = '%.f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Inches'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
df['PrimaryStorageType'].value_counts().plot(kind = 'pie' , autopct =
'%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Screen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Screen'>

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Weight', y='Price_euros',data=df)
plt.xlabel('Weight', fontsize=14, c='k')
plt.ylabel("Price_euros", fontsize=14, c='k')
plt.show()

# %%
sns.scatterplot(x='CPU_freq', y='Price_euros',data=df)
plt.xlabel('CPU_freq', fontsize=14, c='k')
plt.ylabel("Price_euros", fontsize=14, c='k')
plt.show()

# %%
df.tail()
# Out:
#      Company                              Product            TypeName  Inches  \
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#       Ram          OS  Weight  Price_euros    Screen  ScreenW  ...  \
# 1270    4  Windows 10    1.80        638.0   Full HD     1920  ...
# 1271   16  Windows 10    1.30       1499.0  Quad HD+     3200  ...
# 1272    2  Windows 10    1.50        229.0  Standard     1366  ...
# 1273    6  Windows 10    2.19        764.0  Standard     1366  ...
# 1274    4  Windows 10    2.20        369.0  Standard     1366  ...
#
#       RetinaDisplay CPU_company CPU_freq                CPU_model  \
# ...

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x = df['OS'], y= df['Price_euros'])
plt.title('OS VS CPU_freq')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1275 non-null   object
#  3   Inches                1275 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           1275 non-null   object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %%
sns.displot(df['Price_euros'])

# %%
sns.barplot(x=df['Company'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['TypeName'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Inches'])

# %%
sns.scatterplot(x=df['Inches'],y=df['Price_euros'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price_euros'>

# %%
df['Screen'].value_counts()
# Out:
# Screen
# Full HD        835
# Standard       369
# 4K Ultra HD     43
# Quad HD+        28
# Name: count, dtype: int64

# %%
sns.barplot(x=df['CPU_company'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['OS'].value_counts()
# Out:
# OS
# Windows 10      1048
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OS'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['OS'] = df['OS'].apply(cat_os)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram                  OS  Weight  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8                 Mac    1.37
# 1   Apple  Macbook Air  Ultrabook    13.3    8                 Mac    1.34
# 2      HP       250 G6   Notebook    15.6    8  Others/No OS/Linux    1.86
# 3   Apple  MacBook Pro  Ultrabook    15.4   16                 Mac    1.83
# 4   Apple  MacBook Pro  Ultrabook    13.3    8                 Mac    1.37
#
#    Price_euros    Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq  \
# 0      1339.69  Standard     2560  ...            Yes       Intel      2.3
# 1       898.94  Standard     1440  ...             No       Intel      1.8
# 2       575.00   Full HD     1920  ...             No       Intel      2.5
# 3      2537.45  Standard     2880  ...            Yes       Intel      2.7
# 4      1803.60  Standard     2560  ...            Yes       Intel      3.1
#
# ...

# %%
sns.barplot(x=df['OS'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Weight'])

# %%
sns.scatterplot(x=df['Weight'],y=df['Price_euros'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price_euros'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cbar=False,cmap='Blues')
plt.title('Heatmap')
plt.show()

# %%
sns.displot(np.log(df['Price_euros']))

# %%
X = df.drop(columns =['Price_euros'])
y = np.log(df['Price_euros'])

# %%
X
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
y
# Out:
# 0       7.200194
# 1       6.801216
# 2       6.354370
# 3       7.838915
# 4       7.497540
#           ...
# 1270    6.458338
# 1271    7.312553
# 1272    5.433722
# 1273    6.638568
# 1274    5.910797
# Name: Price_euros, Length: 1275, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#      Company              Product            TypeName  Inches  Ram  \
# 944   Lenovo       Yoga 700-11ISK  2 in 1 Convertible    11.3    8
# 21    Lenovo   Legion Y520-15IKBN              Gaming    15.6    8
# 530     Dell         Alienware 17              Gaming    17.3   16
# 279   Lenovo   IdeaPad 320-17IKBR            Notebook    17.3    8
# 398     Dell      Precision M5520         Workstation    15.6    8
# ...      ...                  ...                 ...     ...  ...
# 466     Acer             Aspire 5            Notebook    15.6    4
# 299     Asus  ZenBook UX530UQ-PRO           Ultrabook    15.6   16
# 493     Acer             Aspire 5            Notebook    15.6    8
# 527   Lenovo    IdeaPad 320-15ISK            Notebook    15.6    8
# 1192      HP               250 G6            Notebook    15.6    4
#
#                       OS  Weight       Screen  ScreenW  ScreenH  ...  \
# 944              Windows    1.10      Full HD     1920     1080  ...
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %%
df.head(1)
# Out:
#   Company      Product   TypeName  Inches  Ram   OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  Mac    1.37      1339.69
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3   Core i5
#
#   PrimaryStorage  SecondaryStorage PrimaryStorageType  SecondaryStorageType  \
# 0            128                 0                SSD                    No
#
#    GPU_company               GPU_model
# 0        Intel  Iris Plus Graphics 640
#
# [1 rows x 23 columns]

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,3,5,7,8,10,11,12,14,17,18,19,20])
],remainder='passthrough')

# %%
df.shape
# Out:
# (1275, 23)

# %%
train = df[0:600]

# %%
test = df[601:]

# %%
test.head()
# Out:
#     Company      Product  TypeName  Inches  Ram                  OS  Weight  \
# 601      HP  ProBook 450  Notebook    15.6    4             Windows    2.10
# 602    Acer     Aspire 1  Notebook    14.0    4             Windows    1.60
# 603     MSI   Laptop MSI    Gaming    17.3   16             Windows    4.14
# 604    Dell  Vostro 3568  Notebook    15.6    4  Others/No OS/Linux    2.18
# 605     MSI   GS63VR 7RF    Gaming    15.6   16             Windows    1.80
#
#      Price_euros       Screen  ScreenW  ...  RetinaDisplay CPU_company  \
# 601       668.48     Standard     1366  ...             No       Intel
# 602       329.00      Full HD     1920  ...             No       Intel
# 603      2199.00      Full HD     1920  ...             No       Intel
# 604       465.00     Standard     1366  ...             No       Intel
# 605      2299.00  4K Ultra HD     3840  ...             No       Intel
#
#     CPU_freq                CPU_model PrimaryStorage  SecondaryStorage  \
# ...

# %%
x_train = pd.get_dummies(x_train, drop_first=True)

# %%
from sklearn.preprocessing import LabelEncoder
import warnings
from sklearn.exceptions import DataConversionWarning

# %%
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn.preprocessing._encoders")
warnings.filterwarnings("ignore", category=DataConversionWarning)

# %%
y = df['Price_euros']
x = df.drop('Price_euros',axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=45)

# %%
rf = RandomForestRegressor(n_estimators = 700)
model = rf.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8548152129099189

# %%
X = df.drop(columns =['Price_euros'])
y = np.log(df['Price_euros'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %% [markdown]
# ### RandomForest Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,handle_unknown="ignore",drop='first'),[0,1,2,3,5,7,8,10,11,12,14,17,18,19,20])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.897924661778292
# MAE 0.15394604915260948

# %% [markdown]
# ### Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,handle_unknown="ignore",drop='first'),[0,1,2,3,5,7,8,10,11,12,14,17,18,19,20])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7259363906594586
# MAE 0.2222317817878424
